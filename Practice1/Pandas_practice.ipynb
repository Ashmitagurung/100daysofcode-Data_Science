# %% [markdown]
# Pandas

# %%
import pandas as pd

# %%
data = {
    's.n': [1, 2],
    'name':["Ashmita", "Anupama"],
    'address':["Chabahil", "Chuchepati"]
}

# %%
data
# Out:
# {'s.n': [1, 2],
#  'name': ['Ashmita', 'Anupama'],
#  'address': ['Chabahil', 'Chuchepati']}

# %%
df = pd.DataFrame(data, index=data['s.n'])
df
# Out:
#    s.n     name     address
# 1    1  Ashmita    Chabahil
# 2    2  Anupama  Chuchepati

# %%
df =pd.DataFrame(data)
df
# Out:
#    s.n     name     address
# 0    1  Ashmita    Chabahil
# 1    2  Anupama  Chuchepati

# %%
ser = pd.Series([1, 2, 3, 4])
ser
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
df
# Out:
#    s.n     name     address
# 0    1  Ashmita    Chabahil
# 1    2  Anupama  Chuchepati

# %%
df.name
# Out:
# 0    Ashmita
# 1    Anupama
# Name: name, dtype: object

# %%
df.address
# Out:
# 0      Chabahil
# 1    Chuchepati
# Name: address, dtype: object

# %%
df['name']
# Out:
# 0    Ashmita
# 1    Anupama
# Name: name, dtype: object

# %%
df.iloc[0,1]
# Out:
# 'Ashmita'

# %%
df.loc[0, 'name']
# Out:
# 'Ashmita'

# %%
df.loc[:, ['name', 'address']]
# Out:
#       name     address
# 0  Ashmita    Chabahil
# 1  Anupama  Chuchepati

# %%
df2 = df.iloc[:, 1:]

# %%
df2
# Out:
#       name     address
# 0  Ashmita    Chabahil
# 1  Anupama  Chuchepati

# %%
df2.loc[2] = ['Asha', "Chanchan"]

# %%
df2
# Out:
#       name     address
# 0  Ashmita    Chabahil
# 1  Anupama  Chuchepati
# 2     Asha    Chanchan

# %%
df2['age']=[21, 21, 23]

# %%
df2
# Out:
#       name     address  age
# 0  Ashmita    Chabahil   21
# 1  Anupama  Chuchepati   21
# 2     Asha    Chanchan   23
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df2['age'].plot(kind='hist', bins=20, title='age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# df2.groupby('name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# df2.groupby('address').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['address'].value_counts()
    for x_label, grp in df2.groupby('name')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('name')
_ = plt.ylabel('address')

# %%
df
# Out:
#    s.n     name     address
# 0    1  Ashmita    Chabahil
# 1    2  Anupama  Chuchepati

# %%
df3 = pd.read_csv('/content/drive/MyDrive/data/data.csv')

# %%
df3
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df3['Duration'].plot(kind='hist', bins=20, title='Duration')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df3['Pulse'].plot(kind='hist', bins=20, title='Pulse')
# ...

# %%
from matplotlib import pyplot as plt
df3['Pulse'].plot(kind='hist', bins=20, title='Pulse')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df3[df3['Pulse']<140]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [160 rows x 4 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Duration'].plot(kind='hist', bins=20, title='Duration')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Pulse'].plot(kind='hist', bins=20, title='Pulse')
# ...

# %%
from matplotlib import pyplot as plt
_df_6.plot(kind='scatter', x='Maxpulse', y='Calories', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_1['Pulse'].plot(kind='hist', bins=20, title='Pulse')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df3
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df3.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
df3.tail()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
df3.iloc[10:100]
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 10        60    103       147     329.3
# 11        60    100       120     250.7
# 12        60    106       128     345.3
# 13        60    104       132     379.3
# 14        60     98       123     275.0
# ..       ...    ...       ...       ...
# 95        20    151       168     229.4
# 96        30     95       128     128.2
# 97        25    152       168     244.2
# 98        30    109       131     188.2
# 99        90     93       124     604.1
#
# [90 rows x 4 columns]

# %%
df.shape
# Out:
# (2, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   s.n      2 non-null      int64
#  1   name     2 non-null      object
#  2   address  2 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 176.0+ bytes

# %%
df.drop_duplicates()
# Out:
#    s.n     name     address
# 0    1  Ashmita    Chabahil
# 1    2  Anupama  Chuchepati

# %%
df
# Out:
#    s.n     name     address
# 0    1  Ashmita    Chabahil
# 1    2  Anupama  Chuchepati

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df2
# Out:
#       name     address  age
# 0  Ashmita    Chabahil   21
# 1  Anupama  Chuchepati   21
# 2     Asha    Chanchan   23

# %%
df3
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df3['Duration'].mean()
# Out:
# 63.84615384615385

# %%
df3['Duration'].sum()
# Out:
# 10790

# %%
df3.sum()
# Out:
# Duration    10790.0
# Pulse       18161.0
# Maxpulse    22654.0
# Calories    61629.6
# dtype: float64

# %%
df3.mean()
# Out:
# Duration     63.846154
# Pulse       107.461538
# Maxpulse    134.047337
# Calories    375.790244
# dtype: float64

# %%
df3.std()
# Out:
# Duration     42.299949
# Pulse        14.510259
# Maxpulse     16.450434
# Calories    266.379919
# dtype: float64

# %%
df3['Duration'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df3.describe()
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
df3.corr()
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.155408  0.009403  0.922717
# Pulse    -0.155408  1.000000  0.786535  0.025121
# Maxpulse  0.009403  0.786535  1.000000  0.203813
# Calories  0.922717  0.025121  0.203813  1.000000

# %%
import matplotlib.pyplot as plt
df3.plot(kind='scatter',x='Duration',y='Maxpulse')
# Out:
# <Axes: xlabel='Duration', ylabel='Maxpulse'>

# %%
df3.plot(kind='scatter',x='Duration',y='Calories')
plt.plot([200,200],[0,2000])
plt.show()

# %%
df3
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
df3['Calories'].count()
# Out:
# 164

# %%
df3.plot()
# Out:
# <Axes: >

# %%
df3_cleaned=df3[df3['Calories']>250]

# %%
df3_cleaned.plot()
# Out:
# <Axes: >

# %%
df3.hist()
# Out:
# array([[<Axes: title={'center': 'Duration'}>,
#         <Axes: title={'center': 'Pulse'}>],
#        [<Axes: title={'center': 'Maxpulse'}>,
#         <Axes: title={'center': 'Calories'}>]], dtype=object)

# %%
import seaborn as sns
sns.jointplot(df3,x='Duration',y='Calories')

# %%
df3
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df3_cleaned
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [126 rows x 4 columns]
