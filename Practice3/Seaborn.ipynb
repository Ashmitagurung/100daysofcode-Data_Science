# %% [markdown]
# # Seaborn
#
# **Seaborn by Ashmita Gurung**
#
# > Seaborn is mostly used for statistical plotting in Python.
# > It is built on top of matplotlib and provides beautiful defaults styes and color palettes to make statistical plots more attractive.
# > Seaborn is also closely integrated with Panda's data structures.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import seaborn

# %%
print(seaborn.__version__)
# Out:
# 0.13.1

# %% [markdown]
# **Categories of Plots in Pythons seaborn library**
#
# *  Distributio Plots
# *  Relational Plots
# *   Regression Plots
# *   Categorical Plots
# *   Multi-Plot grids
# *  Matrix Plot

# %% [markdown]
# Plotting Chart Using seaborn Library

# %% [markdown]
# **Line Plot**
# > The seaborn line plot is one of the most basic plots presents in the seaborn library.
# > We use the seaborn line plot mainly to visualize the given data in some time-series form ie. in a continous manner with respect to time.

# %%
import seaborn as sns

# loading dataset
data = sns.load_dataset("iris")

# draw lineplot
sns.lineplot(x="sepal_length", y="sepal_width", data=data)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# **Using seaborn with Matplotliib**
#
# > Just invoke the Seaborn Plotting function as normal and then use Matplotlib's customization function.

# %%
# Loading datasets
data = sns.load_dataset('iris')

#Draw lineplot
sns.lineplot(x = 'sepal_length', y = 'sepal_width', data=data)

#Setting the title using Matplotlib
plt.title('Title using Matplotlib function')

plt.show()

# %% [markdown]
# Setting the xlim and ylim

# %%
# Draw lineplot
sns.lineplot(x = 'sepal_length', y='sepal_width', data = data)

#Setting the x limit of the plot
plt.xlim(5)

plt.show()

# %% [markdown]
# # Creating different types of Plots
#
#
# *   **Relational Plot**
#
#      > Relational Plot
#      > Scatter Plot
#      > Line Plot
#
#
# *  ** Categorical Plot**
#
#      > Count Plot
#      > Box Plot
#      > Violinplot
#      > Stripplot
#      > Swarm Plot
#
#
#
# * **  Distribution Plot**
#      > Histogram
#      > Distplot
#      > JointPlot
#      > Pairplot
#      > Rugplot
#      > KDE plot
#
#
# *  ** Regression Plots:**
#     > Implot
#     >Matrix Plots
#     > Heatmap
#     > ClusterMap

# %% [markdown]
# **Categorical Plots**
#
#
#
# *   Categorical Plots are used where we have to visualize relationship between two numerical values.
#
# *   A more specialized approach can be used if one of the main variable is categorical which means such variables that take on a fixed and limited number of possible values.

# %% [markdown]
# **Bar Plot**

# %%
sns.barplot(x = 'species', y = 'petal_length', data=data)
plt.show()

# %% [markdown]
# **Count Plot**

# %%
sns.countplot(x = 'species', data = data)
plt.show()

# %% [markdown]
# Box Plot
#
#
#
# *   A boxplot is sometimes known as the box and whisker plot.
# *   It shows the distribution of the quantitative data that represents the comparisons between variables.
#
# Syntax:
#
#   boxplot([x, y, hue, data, order, hue_order, …])

# %%
# Box plot

sns.boxplot(x = 'species',y='sepal_width', data =data)
plt.show()

# %% [markdown]
# **ViolinPlot:**
#
#
#
# *   Violin plot is similar to the boxplot except that it provides a higher, more advanced visualiation and uses the kernel density estimation to give a better description about the data distribution.
#
# *  It is created using the violinplot() method.

# %%
sns.violinplot(x = 'species', y = 'sepal_width', data = data)
plt.plot()
# Out:
# []

# %%
# Strip Plot

sns.stripplot(x='species', y='sepal_width', data=data)
plt.show()

# %% [markdown]
# **Distributions Plot:**
#
# Distribution Plots are used for examining univariate and bivariate distributions meaning such distributions that involve one variable or two discrete variables.
#
# **There are various types of distribution Plots:**
#
#
#
#
#
# *   Histogram
#
# *   Distplot
#
# *   Jointplot
#
# *   Pairplot
# *   KDE plot

# %% [markdown]
# **Histogram**
#
#
#
# *   A histogram is basically used to represent data provided in a form of some groups.
# *  It is accurate method for the graphical representation of numerical data distribution.

# %%
sns.histplot(x = 'species', y = 'sepal_width', data = data)
plt.show()

# %%
# Distplot:

sns.displot(data['sepal_length'], kde = True)
plt.show()

# %%
# JointPlot:

sns.jointplot(x='species', y='sepal_width', data=data)
plt.show()

# %%
# Pair Plot

sns.pairplot(data = data, hue = 'species')
plt.show()

# %%
# Rugplot

sns.rugplot(data = data)
plt.show()

# %%
# KDE plot

sns.kdeplot(x = 'sepal_length', y = 'sepal_width', data = data)
plt.show()
